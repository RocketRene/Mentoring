# %%
import os
import shutil
from PIL import Image, ImageDraw
import random



os.chdir('/Users/renekuhn/Downloads')
if os.path.exists('Demo'):
    shutil.rmtree('Demo')

# %%
#Create the demo folder 
if not os.path.exists('Demo'):
    os.makedirs('Demo')
    print("Created Demo folder")
print(os.getcwd())
os.chdir('Demo')
print(os.getcwd())
# Out:
# Created Demo folder
# /Users/renekuhn/Downloads
# /Users/renekuhn/Downloads/Demo

# %%
#define employye list
team = ['Arunas','Vidas','Ludolf','Sina','Levi','Jacob','Kappa','Johannes','Holger']

# %%
#define project list bv = Bauvorhaben  
bv = ['Brandenburger Tor','Bellevue','Bundestag','Elbphilharmonie','Schloss Neuschwanstein']

# %%
#Create emplyee folders
if not os.path.exists('Fairworker'):
    os.makedirs('Fairworker')
    print("Created Fairworker folder")
os.chdir('Fairworker')

for member in team :
    if not os.path.exists(member):
        os.makedirs(member)
        print(f"Created {member} folder")
        for project in bv :
            if not os.path.exists(member+'/'+project):
                os.makedirs(member+'/'+project)
                print(f"Created {project} folder for {member}")

                #Create Sample images in the folders
                for j in range(random.randint(1,10)):
                    img = Image.new('RGB',(400,200),color = (162,71,50))
                    d = ImageDraw.Draw(img)
                    fill = 'Project : '+ project + ' Bauarbeiter : '+member
                    fill = str(fill)
                    d.text((10,10),fill, fill= (255,255,0))

                    v = str(j)
                    img_name = member + '/'+project+'/test'+v+'.png'
                    print(img_name)
                    img.save(img_name)
                    

            


print(os.listdir())
    
    
# Create project upload folders 

# Create random number of images for every project
# Out:
# Created Fairworker folder
# Created Arunas folder
# Created Brandenburger Tor folder for Arunas
# Arunas/Brandenburger Tor/test0.png
# Arunas/Brandenburger Tor/test1.png
# Arunas/Brandenburger Tor/test2.png
# Arunas/Brandenburger Tor/test3.png
# Arunas/Brandenburger Tor/test4.png
# Arunas/Brandenburger Tor/test5.png
# Arunas/Brandenburger Tor/test6.png
# Arunas/Brandenburger Tor/test7.png
# Arunas/Brandenburger Tor/test8.png
# Created Bellevue folder for Arunas
# Arunas/Bellevue/test0.png
# Arunas/Bellevue/test1.png
# Created Bundestag folder for Arunas
# Arunas/Bundestag/test0.png
# Arunas/Bundestag/test1.png
# Arunas/Bundestag/test2.png
# Arunas/Bundestag/test3.png
# Created Elbphilharmonie folder for Arunas
# Arunas/Elbphilharmonie/test0.png
# Created Schloss Neuschwanstein folder for Arunas
# Arunas/Schloss Neuschwanstein/test0.png
# Arunas/Schloss Neuschwanstein/test1.png
# Created Vidas folder
# Created Brandenburger Tor folder for Vidas
# Vidas/Brandenburger Tor/test0.png
# Vidas/Brandenburger Tor/test1.png
# Vidas/Brandenburger Tor/test2.png
# Vidas/Brandenburger Tor/test3.png
# Created Bellevue folder for Vidas
# Vidas/Bellevue/test0.png
# Vidas/Bellevue/test1.png
# Vidas/Bellevue/test2.png
# Vidas/Bellevue/test3.png
# Vidas/Bellevue/test4.png
# Vidas/Bellevue/test5.png
# Created Bundestag folder for Vidas
# Vidas/Bundestag/test0.png
# Vidas/Bundestag/test1.png
# Vidas/Bundestag/test2.png
# Created Elbphilharmonie folder for Vidas
# Vidas/Elbphilharmonie/test0.png
# Vidas/Elbphilharmonie/test1.png
# Vidas/Elbphilharmonie/test2.png
# Created Schloss Neuschwanstein folder for Vidas
# Vidas/Schloss Neuschwanstein/test0.png
# Created Ludolf folder
# Created Brandenburger Tor folder for Ludolf
# Ludolf/Brandenburger Tor/test0.png
# Ludolf/Brandenburger Tor/test1.png
# Ludolf/Brandenburger Tor/test2.png
# Ludolf/Brandenburger Tor/test3.png
# Ludolf/Brandenburger Tor/test4.png
# Ludolf/Brandenburger Tor/test5.png
# Ludolf/Brandenburger Tor/test6.png
# Created Bellevue folder for Ludolf
# Ludolf/Bellevue/test0.png
# Ludolf/Bellevue/test1.png
# Ludolf/Bellevue/test2.png
# Ludolf/Bellevue/test3.png
# Ludolf/Bellevue/test4.png
# Created Bundestag folder for Ludolf
# Ludolf/Bundestag/test0.png
# Created Elbphilharmonie folder for Ludolf
# Ludolf/Elbphilharmonie/test0.png
# Ludolf/Elbphilharmonie/test1.png
# Ludolf/Elbphilharmonie/test2.png
# Ludolf/Elbphilharmonie/test3.png
# Ludolf/Elbphilharmonie/test4.png
# Ludolf/Elbphilharmonie/test5.png
# Ludolf/Elbphilharmonie/test6.png
# Ludolf/Elbphilharmonie/test7.png
# Created Schloss Neuschwanstein folder for Ludolf
# Ludolf/Schloss Neuschwanstein/test0.png
# Created Sina folder
# Created Brandenburger Tor folder for Sina
# Sina/Brandenburger Tor/test0.png
# Sina/Brandenburger Tor/test1.png
# Sina/Brandenburger Tor/test2.png
# Sina/Brandenburger Tor/test3.png
# Sina/Brandenburger Tor/test4.png
# Sina/Brandenburger Tor/test5.png
# Sina/Brandenburger Tor/test6.png
# Sina/Brandenburger Tor/test7.png
# Sina/Brandenburger Tor/test8.png
# Sina/Brandenburger Tor/test9.png
# Created Bellevue folder for Sina
# Sina/Bellevue/test0.png
# Sina/Bellevue/test1.png
# Sina/Bellevue/test2.png
# Sina/Bellevue/test3.png
# Sina/Bellevue/test4.png
# Sina/Bellevue/test5.png
# Sina/Bellevue/test6.png
# Sina/Bellevue/test7.png
# Created Bundestag folder for Sina
# Sina/Bundestag/test0.png
# Sina/Bundestag/test1.png
# Sina/Bundestag/test2.png
# Sina/Bundestag/test3.png
# Sina/Bundestag/test4.png
# Sina/Bundestag/test5.png
# Sina/Bundestag/test6.png
# Sina/Bundestag/test7.png
# Sina/Bundestag/test8.png
# Created Elbphilharmonie folder for Sina
# Sina/Elbphilharmonie/test0.png
# Sina/Elbphilharmonie/test1.png
# Sina/Elbphilharmonie/test2.png
# Sina/Elbphilharmonie/test3.png
# Sina/Elbphilharmonie/test4.png
# Sina/Elbphilharmonie/test5.png
# Sina/Elbphilharmonie/test6.png
# Sina/Elbphilharmonie/test7.png
# Sina/Elbphilharmonie/test8.png
# Created Schloss Neuschwanstein folder for Sina
# Sina/Schloss Neuschwanstein/test0.png
# Sina/Schloss Neuschwanstein/test1.png
# Sina/Schloss Neuschwanstein/test2.png
# Sina/Schloss Neuschwanstein/test3.png
# Sina/Schloss Neuschwanstein/test4.png
# Sina/Schloss Neuschwanstein/test5.png
# Created Levi folder
# Created Brandenburger Tor folder for Levi
# Levi/Brandenburger Tor/test0.png
# Levi/Brandenburger Tor/test1.png
# Levi/Brandenburger Tor/test2.png
# Levi/Brandenburger Tor/test3.png
# Levi/Brandenburger Tor/test4.png
# Created Bellevue folder for Levi
# Levi/Bellevue/test0.png
# Created Bundestag folder for Levi
# Levi/Bundestag/test0.png
# Created Elbphilharmonie folder for Levi
# Levi/Elbphilharmonie/test0.png
# Created Schloss Neuschwanstein folder for Levi
# Levi/Schloss Neuschwanstein/test0.png
# Levi/Schloss Neuschwanstein/test1.png
# Levi/Schloss Neuschwanstein/test2.png
# Levi/Schloss Neuschwanstein/test3.png
# Levi/Schloss Neuschwanstein/test4.png
# Levi/Schloss Neuschwanstein/test5.png
# Created Jacob folder
# Created Brandenburger Tor folder for Jacob
# Jacob/Brandenburger Tor/test0.png
# Jacob/Brandenburger Tor/test1.png
# Jacob/Brandenburger Tor/test2.png
# Jacob/Brandenburger Tor/test3.png
# Jacob/Brandenburger Tor/test4.png
# Jacob/Brandenburger Tor/test5.png
# Jacob/Brandenburger Tor/test6.png
# Created Bellevue folder for Jacob
# Jacob/Bellevue/test0.png
# Jacob/Bellevue/test1.png
# Created Bundestag folder for Jacob
# Jacob/Bundestag/test0.png
# Jacob/Bundestag/test1.png
# Jacob/Bundestag/test2.png
# Jacob/Bundestag/test3.png
# Jacob/Bundestag/test4.png
# Jacob/Bundestag/test5.png
# Jacob/Bundestag/test6.png
# Created Elbphilharmonie folder for Jacob
# Jacob/Elbphilharmonie/test0.png
# Jacob/Elbphilharmonie/test1.png
# Jacob/Elbphilharmonie/test2.png
# Jacob/Elbphilharmonie/test3.png
# Created Schloss Neuschwanstein folder for Jacob
# Jacob/Schloss Neuschwanstein/test0.png
# Jacob/Schloss Neuschwanstein/test1.png
# Jacob/Schloss Neuschwanstein/test2.png
# Jacob/Schloss Neuschwanstein/test3.png
# Jacob/Schloss Neuschwanstein/test4.png
# Jacob/Schloss Neuschwanstein/test5.png
# Jacob/Schloss Neuschwanstein/test6.png
# Jacob/Schloss Neuschwanstein/test7.png
# Created Kappa folder
# Created Brandenburger Tor folder for Kappa
# Kappa/Brandenburger Tor/test0.png
# Kappa/Brandenburger Tor/test1.png
# Kappa/Brandenburger Tor/test2.png
# Kappa/Brandenburger Tor/test3.png
# Kappa/Brandenburger Tor/test4.png
# Created Bellevue folder for Kappa
# Kappa/Bellevue/test0.png
# Kappa/Bellevue/test1.png
# Kappa/Bellevue/test2.png
# Kappa/Bellevue/test3.png
# Created Bundestag folder for Kappa
# Kappa/Bundestag/test0.png
# Kappa/Bundestag/test1.png
# Kappa/Bundestag/test2.png
# Kappa/Bundestag/test3.png
# Kappa/Bundestag/test4.png
# Kappa/Bundestag/test5.png
# Kappa/Bundestag/test6.png
# Created Elbphilharmonie folder for Kappa
# Kappa/Elbphilharmonie/test0.png
# Kappa/Elbphilharmonie/test1.png
# Kappa/Elbphilharmonie/test2.png
# Kappa/Elbphilharmonie/test3.png
# Kappa/Elbphilharmonie/test4.png
# Kappa/Elbphilharmonie/test5.png
# Created Schloss Neuschwanstein folder for Kappa
# Kappa/Schloss Neuschwanstein/test0.png
# Kappa/Schloss Neuschwanstein/test1.png
# Kappa/Schloss Neuschwanstein/test2.png
# Kappa/Schloss Neuschwanstein/test3.png
# Kappa/Schloss Neuschwanstein/test4.png
# Kappa/Schloss Neuschwanstein/test5.png
# Created Johannes folder
# Created Brandenburger Tor folder for Johannes
# Johannes/Brandenburger Tor/test0.png
# Johannes/Brandenburger Tor/test1.png
# Johannes/Brandenburger Tor/test2.png
# Johannes/Brandenburger Tor/test3.png
# Johannes/Brandenburger Tor/test4.png
# Johannes/Brandenburger Tor/test5.png
# Created Bellevue folder for Johannes
# Johannes/Bellevue/test0.png
# Johannes/Bellevue/test1.png
# Johannes/Bellevue/test2.png
# Johannes/Bellevue/test3.png
# Johannes/Bellevue/test4.png
# Created Bundestag folder for Johannes
# Johannes/Bundestag/test0.png
# Johannes/Bundestag/test1.png
# Johannes/Bundestag/test2.png
# Johannes/Bundestag/test3.png
# Johannes/Bundestag/test4.png
# Johannes/Bundestag/test5.png
# Johannes/Bundestag/test6.png
# Created Elbphilharmonie folder for Johannes
# Johannes/Elbphilharmonie/test0.png
# Created Schloss Neuschwanstein folder for Johannes
# Johannes/Schloss Neuschwanstein/test0.png
# Johannes/Schloss Neuschwanstein/test1.png
# Created Holger folder
# Created Brandenburger Tor folder for Holger
# Holger/Brandenburger Tor/test0.png
# Created Bellevue folder for Holger
# Holger/Bellevue/test0.png
# Created Bundestag folder for Holger
# Holger/Bundestag/test0.png
# Holger/Bundestag/test1.png
# Holger/Bundestag/test2.png
# Holger/Bundestag/test3.png
# Holger/Bundestag/test4.png
# Created Elbphilharmonie folder for Holger
# Holger/Elbphilharmonie/test0.png
# Holger/Elbphilharmonie/test1.png
# Holger/Elbphilharmonie/test2.png
# Holger/Elbphilharmonie/test3.png
# Holger/Elbphilharmonie/test4.png
# Holger/Elbphilharmonie/test5.png
# Holger/Elbphilharmonie/test6.png
# Holger/Elbphilharmonie/test7.png
# Created Schloss Neuschwanstein folder for Holger
# Holger/Schloss Neuschwanstein/test0.png
# Holger/Schloss Neuschwanstein/test1.png
# Holger/Schloss Neuschwanstein/test2.png
# Holger/Schloss Neuschwanstein/test3.png
# Holger/Schloss Neuschwanstein/test4.png
# ['Vidas', 'Jacob', 'Levi', 'Arunas', 'Kappa', 'Ludolf', 'Holger', 'Sina', 'Johannes']
